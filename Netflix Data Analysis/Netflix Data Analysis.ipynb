# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np # for linear algebra
import pandas as pd # for Data processing 
import matplotlib.pyplot as plt # for data visualizations
import seaborn as sns # for statistical data visualization

import os 
print(os.listdir('.'))
# Out:
# ['.ipynb_checkpoints', 'Netflix Data Analysis.ipynb', 'netflix_dataset.csv', 'README.md']

# %% [markdown]
# # Loading the Dataset

# %%
NetflixDF = pd.read_csv('netflix_dataset.csv')

# %% [markdown]
# # Displaying the First 5 values

# %%
NetflixDF.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %% [markdown]
# # Shape of the dataset

# %%
NetflixDF.shape
# Out:
# (6234, 12)

# %% [markdown]
# # Printing the name of the columns

# %%
NetflixDF.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Checking fot the null values

# %%
NetflixDF.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Checking for the unique values

# %%
NetflixDF.nunique()
# Out:
# show_id         6234
# type               2
# title           6172
# director        3301
# cast            5469
# country          554
# date_added      1524
# release_year      72
# rating            14
# duration         201
# listed_in        461
# description     6226
# dtype: int64

# %% [markdown]
# # Check for Duplicate values

# %%
NetflixDF.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Making the copy of dataset

# %%
df = NetflixDF.copy()

# %%
df.shape
# Out:
# (6234, 12)

# %% [markdown]
# # Dropping Null values

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (3774, 12)

# %% [markdown]
# # Now printing the first 10 values
